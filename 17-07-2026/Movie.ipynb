# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn import tree

import matplotlib.pyplot as plt
import pickle as pkl
import seaborn as sns

# %%
df=pd.read_csv('Movies.csv')
df
# Out:
#                              Movie_Name Release_Period Whether_Remake  \
# 0                           Golden Boys         Normal             No
# 1                         Kaccha Limboo        Holiday             No
# 2                      Not A Love Story        Holiday             No
# 3                            Qaidi Band        Holiday             No
# 4                             Chaatwali        Holiday             No
# ...                                 ...            ...            ...
# 1693                         Fight Club        Holiday             No
# 1694                 Strings Of Paasion         Normal             No
# 1695              Dunno Y Na Jaane Kyun         Normal             No
# 1696  Taj Mahal - An Eternal Love Story         Normal             No
# 1697                   Mr. Hot Mr. Kool         Normal             No
#
#      Whether_Franchise     Genre New_Actor New_Director New_Music_Director  \
# ...

# %%
movies = df[["Movie_Name", "Genre", "Lead_Star", "Director", "Music_Director"]]

# %%
from sklearn.preprocessing import OneHotEncoder

X = movies[[
    "Genre",
    "Lead_Star",
    "Director",
    "Music_Director"
]]
encoder = OneHotEncoder(handle_unknown="ignore")
X_encoded = encoder.fit_transform(X)
print(X_encoded.shape)
# Out:
# (1698, 2456)

# %%
genre =""
actor = "Ajay Devgan"
director = ""
music = ""

filtered = movies.copy()
if genre:
    filtered = filtered[filtered["Genre"] == genre]
if actor:
    filtered = filtered[filtered["Lead_Star"] == actor]
if director:
    filtered = filtered[filtered["Director"] == director]
if music:
    filtered = filtered[filtered["Music_Director"] == music]
print(filtered["Movie_Name"])
# Out:
# Series([], Name: Movie_Name, dtype: str)

# %%
# Out:
# 5
