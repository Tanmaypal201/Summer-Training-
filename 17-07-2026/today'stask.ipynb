# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn import tree

import matplotlib.pyplot as plt
import pickle as pkl
import seaborn as sns

# %%
df=pd.read_csv('Movies.csv')
df
# Out:
#                              Movie_Name Release_Period Whether_Remake  \
# 0                           Golden Boys         Normal             No
# 1                         Kaccha Limboo        Holiday             No
# 2                      Not A Love Story        Holiday             No
# 3                            Qaidi Band        Holiday             No
# 4                             Chaatwali        Holiday             No
# ...                                 ...            ...            ...
# 1693                         Fight Club        Holiday             No
# 1694                 Strings Of Paasion         Normal             No
# 1695              Dunno Y Na Jaane Kyun         Normal             No
# 1696  Taj Mahal - An Eternal Love Story         Normal             No
# 1697                   Mr. Hot Mr. Kool         Normal             No
#
#      Whether_Franchise     Genre New_Actor New_Director New_Music_Director  \
# ...

# %%
movies = df[["Movie_Name", "Genre", "Lead_Star", "Director", "Music_Director"]]

# %%
X = movies[[
    "Genre",
    "Lead_Star",
    "Director",
    "Music_Director"
]]
Y=movies[["Movie_Name"]]

# %%
print(X_encoded.shape)
# Out:
# (1698, 2456)

# %%
from sklearn.neighbors import NearestNeighbors

knn = NearestNeighbors(
    n_neighbors=20,
    metric="cosine"
)

knn.fit(X_encoded)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=20)

# %%
genre = input("Genre: ")
actor = input("Lead Star: ")
director = input("Director: ")
music = input("Music Director: ")

query = pd.DataFrame({
    "Genre": [genre if genre else ""],
    "Lead_Star": [actor if actor else ""],
    "Director": [director if director else ""],
    "Music_Director": [music if music else ""]
})
# Out:
# Genre:  action
# Lead Star:
# Director:
# Music Director:

# %%
query_encoded = encoder.transform(query)
distances, indices = knn.kneighbors(query_encoded)
recommended_movies = movies.iloc[indices[0]]

print(recommended_movies["Movie_Name"])
# Out:
# 38                         Chakradhaar
# 39                             Players
# 42                               Drona
# 44                              Raavan
# 1636                        Trump Card
# 1637                  Mumbai Godfather
# 1638                       Royal Utsav
# 1656                      Koyelaanchal
# 1624                        Commando 2
# 1625                          Commando
# 1630                 Don Ke Baad Kaun?
# 1568           Karoongi Tujhe Khallaas
# 1565                         Heropanti
# 1566                            Baaghi
# 1567                     Munna Micheal
# 1513                  Rakht Charitra 2
# 1515             Lady Dabangg Aaj Bbhi
# 1479                       Desi Kattey
# 1483    Barood - The Fire A Love Story
# 1490                           Kaafila
# Name: Movie_Name, dtype: str

# %%
print(recommended_movies.shape[0])
# Out:
# 20
