# %%
#Data set of Netfilx
import pandas as pd 

df=pd.read_csv("netflix_dataset.csv")
b=df[["genre","country"]]
print(b)
rating=df[df["rating"]>6][["show_id","country"]]
print(rating)
df.isnull().sum()
df.duplicated("type")
